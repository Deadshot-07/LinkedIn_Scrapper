# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import lxml

# %%
browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get('https://www.linkedin.com/login')
time.sleep(5)

username = 'enter your username here'
password = 'enter your password here'

elementID = browser.find_element_by_id( 'username' )
elementID.send_keys (username)
time.sleep(2)
elementID = browser.find_element_by_id( 'password' )
elementID.send_keys (password)
time.sleep(2)
elementID.submit( )


link = 'https://www.linkedin.com/in/rishabh-singh-61b706114/'
# link - 'https://www.Linkedin.com/in/simran-gandht-024593128/ '
# Link - 'https://www.Linkedin.com/in/smriti-handa-0636045/ '
# Link - 'https://wwww.Linkedin.com/in/charan-nadendla-858a17120/
# link - 'https://www.Linkedin.com/in/mayank-agrawal-1a5883148/
browser.get(link)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# There is no [win32] chromedriver for browser 93.0.4577 in cache
# Get LATEST driver version for 93.0.4577
# Trying to download new driver from https://chromedriver.storage.googleapis.com/93.0.4577.15/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\shrey\.wdm\drivers\chromedriver\win32\93.0.4577.15]

# %%
SCROLL_PAUSE_TIME = 5
# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")
for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to Load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with Last scroll height
    new_height = browser.execute_script("return document.body. scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src,'lxml')
soup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(4) Rishabh Singh | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/3ki0iq40x0w1ti93600pfmk84" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="true" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="https://static-exp1.licdn.com/sc/h/8ekldmhv4d8prk5sml735t6np" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/c3tzo5eqpiygyne7zcvdwrtdj" id="ui-theme" rel="stylesheet"/>
# <link disabled="" href="https://static-exp1.licdn.com/sc/h/3gel9up5xsyxvw50oeledinhc" id="ui-theme-dark" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/6ovygokkblviel3bhvpxy9745" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22aide%22%3A%7B%22isIsolatedBuild%22%3Afalse%7D%2C%22client-sensor-web%22%3A%7B%22mpName%22%3A%22voyager-web%22%7D%2C%22session-record%22%3A%7B%22product%22%3A%22TALENT_SOLUTIONS%22%2C%22lazyLoad%22%3Atrue%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-fetch%22%3A%7B%22preferNative%22%3Atrue%7D%2C%22image-editor%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Atrue%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%2C%22web-vitals-enabled%22%3Atrue%2C%22enable-memory-measurement%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%220.0.0-productspec%2B989bbd37%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22
1.licdn.com/sc/h/4upgxfhayj4r4ly3uoyyw46cp","assets/artdeco-icons/static/images/mercado-icons.svg":"https://static-exp1.licdn.com/sc/h/3ki0iq40x0w1ti93600pfmk84","assets/artdeco-icons/static/images/mercado-reactions/like-consumption/small.svg":"https://static-exp1.licdn.com/sc/h/8ekq8gho1ruaf8i7f86vd1ftt","assets/artdeco-icons/static/images/mercado-reactions/like-consumption/medium.svg":"https://static-exp1.licdn.com/sc/h/2uxqgankkcxm505qn812vqyss","assets/artdeco-icons/static/images/mercado-reactions/like-consumption/large.svg":"https://static-exp1.licdn.com/sc/h/8fz8rai ...
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static-exp1.licdn.com/sc/h/7hun9uv54104msaia8mh2tvwb" name="i18nIntlPolyfillUrl"/>
# <meta content="in" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;3bf0c586-5151-4d12-9f27-ac9089d52076" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.9.2555", "trackingId": [27, 2, 41, -63, 47, -111, 70, -60, -106, 28, 63, -89, 38, 68, 62, 22]}' name="applicationInstance"/>
# <meta content="d7711c6f-e2fd-4243-b80f-318f94b38931" name="clientPageInstanceId"/>
# <meta content="voyager-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.9.2555" name="serviceVersion"/>
# <meta content="AAXLFth/otqYwh+6Um2x8g==" name="treeID"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lixV3Mode":false,"routingLix":{"engines":{"profile":{"lixKey":"voyager.web.profile-tetris","lixedEngine":"profile-tetris"}}},"lix":{"voyager.web.careers-refactor-jam-jobs-home":{"testKey":"voyager.web.careers-refactor-jam-jobs-home","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.careers-search-left-pane-redesign":{"testKey":"voyager.web.careers-search-left-pane-redesign","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.nav.job-posting-jobs-led-entry-points":{"testKey":"voyager.web.nav.job-posting-jobs-led-entry-points","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.iac.web.import-communities":{"testKey":"voyager.iac.web.import-communities","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.careers-search-dash-hits-migration":{"testKey":"voyager.web.careers-search-dash-hits-migration","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.invitations-connect-button-feed":{"testKey":"voyager.web.invitations-connect-button-feed","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.messaging-thread-actions-for-new-conversation-bubble":{"testKey":"voyager.web.messaging-thread-actions-for-new-conversation-bubble","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":{"experimentId":4379345,"segmentIndex":0,"treatmentIndex":1,"urn":"urn:li:member:713648662","trackingUrns":null}},"assessments.screeners.v3.enabled":{"testKey":"assessments.screeners.v3.enabled","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":{"experimentId":4086554,"segmentIndex":1,"treatmentIndex":1,"urn":"urn:li:member:713648662","trackingUrns":null}},"voyager.web.organization-product-remove-review":{"testKey":"voyager.web.organization-product-remove-review","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.search-home-graphql-endpoint":{"testKey":"voyager.web.search-home-graphql-endpoint","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":{"experimentId":4362830,"segmentIndex":1,"treatmentIndex":0,"urn":"urn:li:member:713648662","trackingUrns":null}},"voyager.web.smp-review-invitation":{"testKey":"voyager.web.smp-review-invitation","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.search-convert-pre-marvel-filter-in-request":{"testKey":"voyager.web.search-convert-pre-marvel-filter-in-request","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.premium-atlas-sticky-social-proof":{"testKey":"voyager.web.premium-atlas-sticky-social-proof","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":{"experimentId":4373887,"segmentIndex":1,"treatmentIndex":0,"urn":"urn:li:member:713648662","trackingUrns":null}},"voyager.web.premium-cancel-winback-promotions-pem-tracking":{"testKey":"voyager.web.premium-cancel-winback-promotions-pem-tracking","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.segments-group-first-experience":{"testKey":"voyager.web.segments-group-first-experience","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.video-native-loader-octaned":{"testKey":"voyager.web.video-native-loader-octaned","treatment":"enabled","primaryEvaluationUrn":null,"trackingInfo":null},"voyager.web.onboarding-pymk-typeahead-v2":{"testKey":"voyager.web.onboarding-pymk-typeahead-v2","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":{"experimentId":4150511,"segmentIndex":1,"treatmentIndex":0,"urn":"urn:li:member:713648662","trackingUrns":null}},"voyager.web.mynetwork-refresh-ad":{"testKey":"voyager.web.mynetwork-refresh-ad","treatment":"control","primaryEvaluationUrn":null,"trackingInfo":{"experimentId":4370363,"segmentIndex":1,"treatmentIndex":0,"urn":"urn:li:member:713648662","trackingUrns":null}},"voyager.web.organization-admin-dei-banner":{"t ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="enabled" name="Fastlane"/>
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <meta content="true" name="isQueryTunnelRequestSupported"/>
# <script src="https://static-exp1.licdn.com/sc/h/9lm1w74nbjr3k3lavicf1gdym"></script>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="career-services/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%7D" name="emoji-picker/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events-analytics/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="feed/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="feed-debug/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="feed-detail/config/environment"/>
# <meta content="%7B%7D" name="feed-shared/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/rrweb-record.min.js%22%5D%7D%7D" name="feedback/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="groups/config/environment"/>
# <meta content="%7B%7D" name="hiring/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="inshare/config/environment"/>
# <meta content="%7B%7D" name="interview-prep/config/environment"/>
# <meta content="%7B%7D" name="jam/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="jobs/config/environment"/>
# <meta content="%7B%7D" name="jobs-post-apply/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="jobs-search/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%2C%22assets/rrweb-record.min.js%22%5D%7D%7D" name="jobs-skills-path/config/environment"/>
# <meta content="%7B%7D" name="lead-capture/config/environment"/>
# <meta content="%7B%7D" name="lead-gen/config/environment"/>
# <meta content="%7B%7D" name="marketplace-message-card/config/environment"/>
# <meta content="%7B%7D" name="me/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="me-ca/config/environment"/>
# <meta content="%7B%7D" name="member-analytics/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="messaging/config/environment"/>
# <meta content="%7B%7D" name="msg-conversation-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-hiring/config/environment"/>
# <meta content="%7B%7D" name="msg-mentions/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="msg-overlay/config/environment"/>
# <meta content="%7B%7D" name="msg-overlay-manager/config/environment"/>
# <meta content="%7B%7D" name="msg-reactions/config/environment"/>
# <meta content="%7B%7D" name="msg-referrals/config/environment"/>
# <meta content="%7B%7D" name="msg-shared-modals/config/environment"/>
# <meta content="%7B%7D" name="msg-spinmail/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="msg-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-video-call/config/environment"/>
# <meta content="%7B%7D" name="mynetwork/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="news/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="notifications/config/environment"/>
# <meta content="%7B%7D" name="onboarding/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization/config/environment"/>
# <meta content="%7B%7D" name="organization-about/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-admin/config/environment"/>
# <meta content="%7B%7D" name="organization-content-suggestions/config/environment"/>
# <meta content="%7B%7D" name="organization-employee-experience/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-events/config/environment"/>
# <meta content="%7B%7D" name="organization-insights/config/environment"/>
# <meta content="%7B%7D" name="organization-jobs/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-life/config/environment"/>
# <meta content="%7B%7D" name="organization-people/config/environment"/>
# <meta content="%7B%7D" name="organization-posts/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-videos/config/environment"/>
# <meta content="%7B%7D" name="participate-text-editor/config/environment"/>
# <meta content="%7B%7D" name="premium/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="products/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile/config/environment"/>
# <meta content="%7B%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-edit/config/environment"/>
# <meta content="%7B%7D" name="profile-ge/config/environment"/>
# <meta content="%7B%7D" name="profile-opportunities/config/environment"/>
# <meta content="%7B%7D" name="profile-search-analytics/config/environment"/>
# <meta content="%7B%7D" name="profile-skill-assessments/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-subroutes/config/environment"/>
# <meta content="%7B%7D" name="profile-tetris/config/environment"/>
# <meta content="%7B%7D" name="props-home/config/environment"/>
# <meta content="%7B%7D" name="publishing/config/environment"/>
# <meta content="%7B%7D" name="publishing-entity/config/environment"/>
# <meta content="%7B%7D" name="resume-builder/config/environment"/>
# <meta content="%7B%7D" name="rooms/config/environment"/>
# <meta content="%7B%7D" name="salary-engine/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="search/config/environment"/>
# <meta content="%7B%7D" name="service-marketplace/config/environment"/>
# <meta content="%7B%7D" name="sharing-v2/config/environment"/>
# <meta content="%7B%7D" name="smp-service-pages/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="stories-ads-engine/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="stories-engine/config/environment"/>
# <meta content="%7B%7D" name="tenor-gif/config/environment"/>
# <meta content="%7B%7D" name="tracking-overlay/config/environment"/>
# <meta content="%7B%7D" name="unemployment/config/environment"/>
# <meta content="%7B%7D" name="video-conferencing/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="video-engine/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="video-go-live/config/environment"/>
# <meta content="%7B%7D" name="video-intro/config/environment"/>
# <meta content="%7B%7D" name="workflow/config/environment"/>
# <link href="https://static-exp1.licdn.com/sc/h/9d7j9atn0scg8hrs6sy51zscr" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h
rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/9bokhaa6csguqgemz9wrhh2o8"></script><link href="https://static-exp1.licdn.com/sc/h/b3g3kak0tqtt9jml6erjy211c" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/713twpe74fl4xx84p36anyqad"></script><link href="https://static-exp1.licdn.com/sc/h/dxkwsengd98o93ycyoxo0wl18" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/4z7iuvezipuitxvglais1jf2j"></script><link href="https://static-exp1.licdn.com/sc/h/9rq7r8fp6gc83621oia7ul7le" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/b606b6cokkpnqt92o04c3s8aw"></script><script src="https://static-exp1.licdn.com/sc/h/vmm5d0x5fy4nw9y6atpwpo9i"></script><link href="https://static-exp1.licdn.com/sc/h/8aq0k9myv3fs9d4wy5xcjires" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/coa7f3ykpl4n59lxspa6n42h5"></script><script src="https://static-exp1.licdn.com/sc/h/99ova21j15fkam4yqnlvnqrgp"></script><link href="https://static-exp1.licdn.com/sc/h/7xs31y72x1o3dtegjooyr47zp" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/5nna65uely5yik2k7p9zacu6n"></script><link href="https://static-exp1.licdn.com/sc/h/ruxgjyqb5mupnj31puhb3dun" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/4e4wjgszy57jmy8mj3weq04tp"></script><link href="https://static-exp1.licdn.com/sc/h/53kql3vi3q9rsy44vnhfolf32" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/121anlw5n430wwo3adgwy9jdt"></script><link href="https://static-exp1.licdn.com/sc/h/1xz6h523q08j1rsibs2zkvbx8" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/373emvdsaytk13pam04s7hi5n"></script><link href="https://static-exp1.licdn.com/sc/h/1erwjl7yyo5w502n9rk4achg3" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/2anornghj3a2pw7irzhk4vfrz"></script><link href="https://static-exp1.licdn.com/sc/h/6keafsue8z1jnwm60ropg4et" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/8fb0yxn8np06bla26mrisylcy"></script><link href="https://static-exp1.licdn.com/sc/h/78svclr54w30ec9ywiwaygkpi" rel="stylesheet"/></head><body class="render-mode-BIGPIPE nav-v2 ember-application icons-loaded boot-complete" data-t-link-to-event-attached="true" dir="ltr"><meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://in/rishabh-singh-61b706114/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
# <!-- HUED-11420 -->
# <div id="artdeco-toasts__wormhole"> <section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>
# </div>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <div class="app-boot-bg-skeleton" id="app-boot-bg-loader">
# <div class="top-bar"></div>
# <div class="content">
# <div class="initial-load-animation fade-load">
# <div class="linkedin-image display-flex justify-center">
# <svg class="loader__linkedin-logo" height="48" viewbox="0 0 190 48" width="190" xmlns="http://www.w3.org/2000/svg">
# <g>
# <g>
style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:nZx6/1e1AAbOHh075gv083zrunZT186/K+rx5FP70A4=","elements":[{"lixTracking":{"urn":"urn:li:member:713648662","segmentIndex":4,"experimentId":4343519,"treatmentIndex":0,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"search-global-typeahead/templates/components/search-global-typeahead","locale":"en_US","message":"Search","key":"i18n_search_short_placeholder","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"lixTreatment":"overwrittenControl","lixKey":"chameleon.JS:us.copy.17854","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:713648662","segmentIndex":2,"experimentId":4358724,"treatmentIndex":1,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"premium/templates/components/chooser/plan-card","locale":"en_US","message":"Learn more","key":"i18n_card_select_plan","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"card_select_plan","description":"testing 'Learn more' on SKU cards, vs control of 'Select plan' ","lixTreatment":"VAR_t20152_PR_1","lixKey":"chameleon.PREMIUM:us.copy.17654","creatorDisplayName":"cyount","status":"PERMANENT_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:713648662","segmentIndex":3,"experimentId":3417563,"treatmentIndex":0,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"organization-base/templates/components/top-card/secondary-content","locale":"en_US","message":"{:connection,name} {:count,choice,0#works|1#&amp; {:count,number,integer} other {:count,choice,singular#connection|plural#connections} work} here","key":"i18n_org_connections_work_here","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"CompanyPage_MessageCTA","description":"Adding \"Message\" and alternative copy variations on Company Page where we show mutual connections. Assessing whether using active copy that reflects the next best action drives lifts in unique message senders and messages sent.","lixTreatment":"control","lixKey":"chameleon.MESSAGING:en.copy.8966","creatorDisplayName":"crowshan","status":"MAX_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"}],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118575" style="display: none">
#   {"request":"/voyager/api/chameleonConfig","status":200,"body":"bpr-guid-1118575","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1118575" src="..." style="display: none"/><code id="bpr-guid-1118576" style="display: none">
#   {"data":{"canBrowseProfiles":false,"reactivationFeaturesEligible":false,"canViewJobAnalytics":false,"canViewWVMP":false,"premiumFreeTrialEligible":true,"canAccessLearningVideos":false,"premiumLearningUpgradeEligible":false,"canViewCompanyInsights":false,"$type":"com.linkedin.voyager.premium.FeatureAccess"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118576" style="display: none">
#   {"request":"/voyager/api/premium/featureAccess?name\u003DreactivationFeaturesEligible","status":200,"body":"bpr-guid-1118576","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1118576" src="..." style="display: none"/><code id="bpr-guid-1118577" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:uPYuDSPXzooiHx+zPOguG1+f+JFMWTWFEfhiIQtEFMM=","elements":[],"paging":{"count":10,"start":0,"total":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118577" style="display: none">
#   {"request":"/voyager/api/takeovers","status":200,"body":"bpr-guid-1118577","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-
"com.linkedin.common.VectorArtifact"},{"width":400,"fileIdentifyingUrlPathSegment":"400_400/0/1629829329259?e=1630760400&amp;v=beta&amp;t=qP96khTqsiHZvAEWGAIUVPn_zAzVQT1UAjN3d5WA3sA","expiresAt":1630760400000,"height":400,"$type":"com.linkedin.common.VectorArtifact"},{"width":800,"fileIdentifyingUrlPathSegment":"800_800/0/1629829329259?e=1630760400&amp;v=beta&amp;t=S-sCQ7QJUrOuegNaLNWtIlnX_ZZS6u6hSKN--SUA3Gw","expiresAt":1630760400000,"height":800,"$type":"com.linkedin.common.VectorArtifact"},{"width":100,"fileIdentifyingUrlPathSegment":"100_100/0/1629829329259?e=1630760400&amp;v=beta&amp;t=rKXwTpwutMO9IOeYhbvDhpcclRvOu_myy5jq-aN3-LY","expiresAt":1630760400000,"height":100,"$type":"com.linkedin.common.VectorArtifact"}],"rootUrl":"https://media-exp1.licdn.com/dms/image/D4E35AQHXzEKbWGxKOA/profile-framedphoto-shrink_","$type":"com.linkedin.common.VectorImage"},"$type":"com.linkedin.voyager.identity.shared.MiniProfile","firstName":"Shreyansh","entityUrn":"urn:li:fs_miniProfile:ACoAACqJahYBn3SqOmZG7jtIt5BfWV46QbHm8UY","publicIdentifier":"shreyansh-rastogi","trackingId":"S0B/W8u+RP2gBXIXYcAD6Q=="}]}
# </code>
# <code id="datalet-bpr-guid-1118580" style="display: none">
#   {"request":"/voyager/api/me","status":200,"body":"bpr-guid-1118580","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1118580" src="..." style="display: none"/><code id="bpr-guid-1118581" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:7ZvAwvPwYldk7Tvl3jXgC4ymrtxthgc+3EdE7ncMd98=","elements":[{"count":0,"tab":"MY_NETWORK","$type":"com.linkedin.voyager.common.communications.TabBadge"},{"count":0,"tab":"MESSAGING","$type":"com.linkedin.voyager.common.communications.TabBadge"},{"count":4,"tab":"NOTIFICATIONS","$type":"com.linkedin.voyager.common.communications.TabBadge"}],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118581" style="display: none">
#   {"request":"/voyager/api/voyagerCommunicationsTabBadges?q\u003DtabBadges\u0026countFrom\u003D0","status":200,"body":"bpr-guid-1118581","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1118581" src="..." style="display: none"/><code id="bpr-guid-1118582" style="display: none">
#   {"data":{"versionTag":"1509652141","$type":"com.linkedin.voyager.identity.profile.VersionTag"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118582" style="display: none">
#   {"request":"/voyager/api/identity/profiles/ACoAACqJahYBn3SqOmZG7jtIt5BfWV46QbHm8UY/versionTag","status":200,"body":"bpr-guid-1118582","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1118582" src="..." style="display: none"/><code id="bpr-guid-1118583" style="display: none">
#   {"data":{"fullLastNameShown":false,"formerNameVisibilitySetting":"PUBLIC","discloseAsProfileViewer":"DISCLOSE_FULL","messagingSeenReceipts":null,"allowProfileEditBroadcasts":null,"messagingTypingIndicators":null,"profileVideoVisibilitySetting":"MEMBERS","entityUrn":"urn:li:fsd_privacySettings:singleton","publicProfilePictureVisibilitySetting":"PUBLIC","pronounVisibilitySetting":"MEMBERS","requireReferral":null,"showPublicProfile":true,"$recipeTypes":["com.linkedin.voyager.dash.deco.identity.profile.PrivacySettings"],"$type":"com.linkedin.voyager.dash.identity.profile.PrivacySettings","allowOpenProfile":false,"profilePictureVisibilitySetting":"PUBLIC","namePronunciationVisibilitySetting":"CONNECTIONS"},"meta":{"microSchema":{"version":"2","types":{"com.linkedin.voyager.dash.deco.identity.profile.PrivacySettings":{"fields":{"fullLastNameShown":{"type":"boolean"},"requireReferral":{"type":"boolean"},"showPublicProfile":{"type":"boolean"},"formerNameVisibilitySetting":{"type":"string"},"messagingSeenReceipts":{"type":"string"},"discloseAsProfileViewer":{"type":"string"},"allowProfileEditBroadcasts":{"type":"boolean"},"messagingTypingIndicators":{"type":"string"},"allowOpenProfile":{"type":"boolean"},"profilePictureVisibilitySetting":{"type":"string"},"profileVideoVisibilitySetting":{"type":"string"},"entityUrn":{"type":"string"},"publicProfilePictureVisibilitySetting":{"type":"string"},"namePronunciationVisibilitySetting":{"type":"string"},"pronounVisibilitySetting":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.identity.profile.PrivacySettings"}}}},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118583" style="display: none">
#   {"request":"/voyager/api/identity/dash/profilePrivacySettings?decorationId\u003Dcom.linkedin.voyager.dash.deco.identity.profile.PrivacySettings-11","status":200,"body":"bpr-guid-1118583","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1118583" src="..." style="display: none"/><code id="bpr-guid-1118584" style="display: none">
#   {"data":{"messagingTypingIndicators":"ALL_ENABLED","allowOpenProfile":false,"profilePictureVisibilitySetting":"PUBLIC","entityUrn":"urn:li:fs_privacySettings:ACoAACqJahYBn3SqOmZG7jtIt5BfWV46QbHm8UY","showPublicProfile":true,"showPremiumSubscriberBadge":false,"publicProfilePictureVisibilitySetting":"PUBLIC","formerNameVisibilitySetting":"PUBLIC","messagingSeenReceipts":"ALL_ENABLED","allowProfileEditBroadcasts":true,"$type":"com.linkedin.voyager.identity.profile.PrivacySettings"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1118584" style="display: none">
#   {"request":"/voyager/api/identity/profiles/rishabh-singh-61b706114/privacySettings","status":200,"body":"bpr-guid-1118584","method":"GET"}
# ...
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Hello,
# I am Shreyansh, currently, I am a 2nd-year student at St.Xavier's college pursuing  SYBsc(Maths). I am looking out for an internship in the field of- Data analytics or anything closer to this field at your firm, please let me know if there is any.
# It would be great if you could help me out.
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="James Barboza" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember545" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4D03AQGEEDF5aQM6_A/profile-displayphoto-shrink_100_100/0/1625464134667?e=1635984000&amp;v=beta&amp;t=6oOs77A0kzl6-yl8UfRy07B5RQ223I4cyuqisCoId2Q"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator presence-indicator--is-reachable presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is reachable
#   </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember544" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember544">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               James Barboza
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Mar 9, 2020
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Hello,
# I am Shreyansh, currently, I am a 2nd-year student at St.Xavier's college pursuing  SYBsc(Maths). I am looking out for an internship in the field of- Data analytics or anything closer to this field at your firm, please let me know if there is any.
#
# shreyanshrastogi987@gmail.com
# +91-8171796728
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="Aniruddha Choudhary" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember548" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5103AQGQ1yBstcbXbQ/profile-displayphoto-shrink_100_100/0/1517427517380?e=1635984000&amp;v=beta&amp;t=worB2910gajUNddqkgQ79FhPBmegxuDy7g8m0GH_lB4"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator presence-indicator--is-reachable presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is reachable
#   </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember547" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember547">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Aniruddha Choudhary
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Mar 9, 2020
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Hello,
# I am Shreyansh, currently, I am a 2nd-year student at St.Xavier's college pursuing  SYBsc(Maths). I am looking out for an internship in the field of- Data analytics or anything closer to this field at your firm, please let me know if there is any.
# It would be great if you could help me out.
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="Mrigansh Kulshrestha" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember551" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5603AQHB298eFycwdg/profile-displayphoto-shrink_100_100/0/1517232387245?e=1635984000&amp;v=beta&amp;t=xPxMwQytOYevQydaZLxxpuCNzqqM4CRgK75CYJeMxm4"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator presence-indicator--is-reachable presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is reachable
#   </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember550" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember550">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Mrigansh Kulshrestha
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Mar 9, 2020
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Hello,
# I am Shreyansh, currently, I am a 2nd-year student at St.Xavier's college pursuing  SYBsc(Maths). I am looking out for an internship in the field of- Data analytics or anything closer to this field at your firm, please let me know if there is any.
#
# shreyanshrastogi987@gmail.com
# +91-8171796728
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="Abhishek Javadekar" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember554" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4E03AQHpRRGgAEYYCQ/profile-displayphoto-shrink_100_100/0/1581629707243?e=1635984000&amp;v=beta&amp;t=NWwMPjhhvuI49RjN4dtRfSYyQPHJuL0FmP--wO1v4QM"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is offline
#       </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember553" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember553">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Abhishek Javadekar
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Mar 9, 2020
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Hello,
# I am Shreyansh, currently, I am a 2nd-year student at St.Xavier's college pursuing  SYBsc(Maths). I am looking out for an internship in the field of- Data analytics or anything closer to this field at your firm, please let me know if there is any.
# It would be great if you could help me out.
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="Jadyn Ferreira" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember557" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5103AQGOU82IHnjsyA/profile-displayphoto-shrink_100_100/0/1578311087607?e=1635984000&amp;v=beta&amp;t=S2qPnLNFAGQed5kzol0N7EKXB1RA11zEm_eF3F-RY7k"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is offline
#       </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember556" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember556">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Jadyn Ferreira
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Mar 6, 2020
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Hello, this is Shreyansh Rastogi,  student of St. Xavier's College, Mumbai. I am a  SYBsc(Maths)  student looking for an internship in the field of data analyst or in operations. So if there are position available for the respective please let me know.
# shreyanshrastogi987@gmail.com
# +91-817-179-6728
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- --> <div class="msg-overlay-list-bubble__loader hidden">
# <div class="artdeco-loader artdeco-loader--small ember-view" id="ember174"><!-- -->
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# </div>
# </div>
# <!-- --> </div>
# <!-- --></div>
# </section>
# <!-- --><!-- --></div>
# <!-- -->
# <!-- -->
# <div id="msg-overlay__emoji-hoverable-outlet"></div>
# </aside>
# <img alt="" class="third-party-tracking-pixel hidden" data-test-third-party-tracking-pixel="" role="none" src="https://px.ads.linkedin.com/collect/?pid=6883&amp;fmt=gif&amp;_t=1630673867450"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"></div>
# <div class="entity-hovercard-container hidden ember-view" id="ember84"><div class="entity-hovercard p4" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div></div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <iframe sandbox="allow-scripts" src="//radar.cedexis.com/1/11326/radar.html" style="display:none;" title="cedex beacon iframe">
# </iframe>
# <div><!-- --></div></body></html>

# %% [markdown]
# # Info

# %%
loc = soup.find('span',{'class':'text-body-small inline t-black--light break-words'}).get_text().strip()
loc
# Out:
# 'Bangalore Urban, Karnataka, India'

# %%
name = soup.find('h1',{'class':'text-heading-xlarge inline t-24 v-align-middle break-words'}).get_text().strip()
name
# Out:
# 'Rishabh Singh'

# %%
loc = soup.find('span',{'class':'text-body-small inline t-black--light break-words'}).get_text().strip()
loc
# Out:
# 'Bangalore Urban, Karnataka, India'

# %%
connection = soup.find('span',{'class':'t-bold'}).get_text().strip()
connection
# Out:
# '500+'

# %% [markdown]
# # Experience

# %%
exp_section = soup.find('section',{'id':'experience-section'})
print(exp_section)
# Out:
# <section class="pv-profile-section experience-section ember-view" id="experience-section"><header class="pv-profile-section__card-header">
# <h2 class="pv-profile-section__card-heading">
#     Experience
#   </h2>
# <!-- --></header>
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember364"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1517647779"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/honeywell/" id="ember366"> <div class="pv-entity__logo company-logo">
# <img alt="Honeywell" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember368" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560BAQFvcIh3UnA5zw/company-logo_100_100/0/1535662846602?e=1639008000&amp;v=beta&amp;t=o9oD0yzrQ6eMvfWN3rDgWPknwJDwP5uTNQ_fNZxCXNM"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       Honeywell
#         <span class="pv-entity__secondary-title separator">Full-time</span>
# </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Aug 2019 – May 2021</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 10 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bengaluru Area, India</span>
# </h4>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <!-- --> </div>
# </section>
# </li><li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember370"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="929137672"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/l&amp;t-technology-services-limited/" id="ember372"> <div class="pv-entity__logo company-logo">
# <img alt="L&amp;T Technology Services Limited" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember374" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C510BAQFFdHnl8nr2KA/company-logo_100_100/0/1580388652067?e=1639008000&amp;v=beta&amp;t=ssKeT4u5jo4qbf2jhBiLpqxzPJQmWpt-P6kPfzG5EuY"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Design Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       L&amp;T Technology Services Limited
#         <span class="pv-entity__secondary-title separator">Full-time</span>
# </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Jan 2017 – Jul 2019</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">2 yrs 7 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bengaluru Area, India</span>
# </h4>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <!-- --> </div>
# </section>
# </li> </ul>
# <!-- --></section>

# %%
exp_section = exp_section.find('ul')
li_tags = exp_section.find('li')

# %%
a_tags = li_tags.find('a')
a_tags
# Out:
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/honeywell/" id="ember366"> <div class="pv-entity__logo company-logo">
# <img alt="Honeywell" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember368" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560BAQFvcIh3UnA5zw/company-logo_100_100/0/1535662846602?e=1639008000&amp;v=beta&amp;t=o9oD0yzrQ6eMvfWN3rDgWPknwJDwP5uTNQ_fNZxCXNM"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       Honeywell
#         <span class="pv-entity__secondary-title separator">Full-time</span>
# </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Aug 2019 – May 2021</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 10 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bengaluru Area, India</span>
# </h4>
# <!-- -->
# </div>
# </a>

# %%
job_title = a_tags.find('h3').get_text().strip()
job_title
# Out:
# 'FPGA Engineer'

# %%
company_name = a_tags.find_all('p')[1].get_text().strip()
company_name
# Out:
# 'Honeywell\n        Full-time'

# %%
joining_date = a_tags.find_all('h4')[0].find_all('span')[1].get_text().strip()
joining_date
# Out:
# 'Aug 2019 – May 2021'

# %%
exp = a_tags.find_all('h4')[1].find_all('span')[1].get_text().strip()
exp
# Out:
# '1 yr 10 mos'

# %% [markdown]
# # Education

# %%
edu_section = soup.find('section',{'id':'education-section'}).find('ul')
edu_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="356637700"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/school/223389/?legacySchoolId=223389" id="ember379"> <div class="pv-entity__logo">
# <img alt="Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school ember-view" id="ember381" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">Bachelor of Engineering (B.E.)</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">Electrical, Electronics and Communications Engineering</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__grade t-14 t-black t-normal">
# <span class="visually-hidden">Grade</span>
# <span class="pv-entity__comma-item">FIRST</span>
# </p>
# </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2012</time> – <time>2016</time>
# </span>
# </p>
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div></li>
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="373985416"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" href="/search/results/all/?keywords=S.H.S.B.B" id="ember383">
# <div class="pv-entity__logo">
# <img alt="S.H.S.B.B" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school ember-view" id="ember385" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">S.H.S.B.B</h3>
# <!-- --> <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">PCM</span>
# </p>
# <!-- --> </div>
# <!-- -->
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div></li>
# </ul>

# %%
college_name = edu_section.find('h3').get_text().strip()
college_name
# Out:
# 'Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021'

# %%
degree_name = edu_section.find('p',{'class':'pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal'}).find_all('span')[1].get_text()
degree_name
# Out:
# 'Bachelor of Engineering (B.E.)'

# %%
stream_name = edu_section.find('p',{'class':'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text()
stream_name
# Out:
# 'Electrical, Electronics and Communications Engineering'

# %%
degree_year = edu_section.find('p',{'class':'pv-entity__dates t-14 t-black--light t-normal'}).find_all('span')[1].get_text().
degree_year
# Out:
# '\n2012 – 2016\n'

# %%
info = [link,name,loc,connection,job_title,company_name,joining_date,exp,college_name,degree_name,stream_name,degree_year]
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  'Bangalore Urban, Karnataka, India',
#  '500+',
#  'FPGA Engineer',
#  'Honeywell\n        Full-time',
#  'Aug 2019 – May 2021',
#  '1 yr 10 mos',
#  'Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021',
#  'Bachelor of Engineering (B.E.)',
#  'Electrical, Electronics and Communications Engineering',
#  '\n2012 – 2016\n']
